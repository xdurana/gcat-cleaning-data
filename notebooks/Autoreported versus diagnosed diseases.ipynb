# %% [markdown]
# # Autoreported versus diagnosed diseases

# %%
import difflib
import re
import numpy as np
import pandas as pd
import matplotlib as mpl
import matplotlib.pyplot as plt
from matplotlib.pylab import *
import seaborn as sns

# %matplotlib inline

# %%
rr = pd.read_csv('/home/labs/dnalab/xduran/Downloads/gcat_diagnostics_icd_3_rr.csv', low_memory=False)
rr = log1p(rr)
rr = rr.set_index(rr.columns)
rr = rr[(rr.T != 0).any()]
rr = rr.loc[:, (rr != 0).any(axis=0)]

# %%
plt.figure(figsize=[12,10])
sns.heatmap(rr)
plt.savefig("heatmap.svg")
